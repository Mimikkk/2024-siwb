# %% [markdown]
# # Projekt 4: Generalna ocena jakości modeli przestrzennych RNA

# %%
# %pip install pandas biopython nglview

# %%
import xml.etree.ElementTree as ET
from pathlib import Path

import pandas as pd
from Bio.PDB import PDBParser

# %% [markdown]
# 1. Zapoznanie się z udostępnionymi zbiorami danych i ewentualne przetransformowanie ich do postaci ułatwiającej zastosowanie technik sztucznej inteligencji np. integracja danych składowych przechowywanych w różnych formatach z wykorzystaniem jednej spójnej reprezentacji.

# %%
DATASET_PATH = Path("./resources/datasets/RNA-Puzzles")

challenges = [f"pz{index:02}" for index in range(1, 11)]

# %%
def parse_motifs(challenges: list[str]) -> pd.DataFrame:
    result_df = pd.DataFrame()
    for challenge in challenges:
        current_df = pd.read_csv(
            DATASET_PATH / f"{challenge}/filter-results.txt",
            sep="\t",
            header=None,
            names=[
                "filename",
                "number_of_segments",
                "number_of_residues",
                "nucleotide_ranges",
                "sequences",
            ],
        )
        current_df["challenge_number"] = challenge
        result_df = pd.concat([result_df, current_df])

    # UWAGA! Warto ograniczyć analizy do motywów strukturalnie złożonych składających się z przynajmniej dwóch,
    # a najlepiej trzech lub więcej segmentów.
    result_df = result_df[result_df["number_of_segments"] >= 3]
    return result_df.reset_index(drop=True)


motifs = parse_motifs(challenges)
motifs
# Out:
#                           filename  number_of_segments  number_of_residues  \
# 0           1_solution_0_rpr_A_4_C                   3                  20
# 1           1_solution_0_rpr_A_5_C                   3                  23
# 2           1_solution_0_rpr_A_6_G                   3                  24
# 3           1_solution_0_rpr_A_7_C                   3                  24
# 4           1_solution_0_rpr_A_8_G                   3                  24
# ..                             ...                 ...                 ...
# 673  10_0_solution_4LCK_rpr_B_55_C                   3                  32
# 674  10_0_solution_4LCK_rpr_B_56_G                   3                  38
# 675  10_0_solution_4LCK_rpr_B_57_A                   4                  42
# 676  10_0_solution_4LCK_rpr_B_58_A                   4                  43
# 677  10_0_solution_4LCK_rpr_B_59_U                   4                  36
#
#                       nucleotide_ranges  \
# 0               A1-A8, B10-B16, B19-B23
# 1                A1-A9, B8-B15, B18-B23
# 2               A2-A10, B7-B14, B17-B23
# 3               A3-A11, B6-B13, B16-B22
# 4               A4-A12, B5-B12, B15-B21
# ..                                  ...
# 673           A48-A63, B16-B21, B50-B59
# 674           A48-A64, B15-B22, B49-B61
# 675  A49-A54, A58-A64, B14-B22, B44-B63
# 676   A59-A63, B6-B11, B13-B23, B43-B63
# 677   B6-B10, B12-B22, B44-B52, B54-B64
#
#                                              sequences challenge_number
# 0                             CCGCCGCG, CAUGCCU, GGCGG             pz01
# 1                          CCGCCGCGC, GCCAUGCC, UGGCGG             pz01
# 2                         CGCCGCGCC, CGCCAUGC, GUGGCGG             pz01
# 3                         GCCGCGCCA, GCGCCAUG, UGUGGCG             pz01
# 4                         CCGCGCCAU, CGCGCCAU, CUGUGGC             pz01
# ..                                                 ...              ...
# 673               AGGAUAGUGAAAGCUA, UGGUAG, GGGUUCGAAU             pz10
# 674         AGGAUAGUGAAAGCUAG, GUGGUAGA, CGGGUUCGAAUCC             pz10
# 675   GGAUAG, AAGCUAG, AGUGGUAGA, GGUCGCGGGUUCGAAUCCCG             pz10
# 676  AGCUA, AGUAGU, CAGUGGUAGAA, GGGUCGCGGGUUCGAAUCCCG             pz10
# 677         AGUAG, UCAGUGGUAGA, GGUCGCGGG, UCGAAUCCCGU             pz10
#
# [678 rows x 6 columns]

# %%
def parse_xml(xml_path: Path) -> pd.DataFrame:
    tree = ET.parse(xml_path)
    root = tree.getroot()
    return pd.DataFrame(
        [
            {
                "filename": child.find("description").find("filename").text,
                "score": child.find("score").text,
            }
            for child in root
        ]
    )


def parse_scores(motifs: pd.DataFrame) -> pd.DataFrame:
    result_df = pd.DataFrame()
    for index, row in motifs.iterrows():
        xml_path = DATASET_PATH / f"{row['challenge_number']}" / f"{row['filename']}-rmsd.xml"

        if xml_path.exists():
            current_df = parse_xml(xml_path)
            current_df["solution"] = row["filename"]
            result_df = pd.concat([result_df, current_df])
        else:
            motifs.drop(index, inplace=True)

    return result_df


scores = parse_scores(motifs)
scores
# Out:
#                 filename  score                       solution
# 0   1_bujnicki_1_rpr.pdb  4.769         1_solution_0_rpr_A_4_C
# 1   1_bujnicki_2_rpr.pdb  4.594         1_solution_0_rpr_A_4_C
# 2   1_bujnicki_3_rpr.pdb  3.921         1_solution_0_rpr_A_4_C
# 3   1_bujnicki_4_rpr.pdb  4.522         1_solution_0_rpr_A_4_C
# 4   1_bujnicki_5_rpr.pdb  4.616         1_solution_0_rpr_A_4_C
# ..                   ...    ...                            ...
# 21     10_DING_5_rpr.pdb  4.516  10_0_solution_4LCK_rpr_B_59_U
# 22     10_DING_6_rpr.pdb  3.939  10_0_solution_4LCK_rpr_B_59_U
# 23     10_DING_7_rpr.pdb  4.639  10_0_solution_4LCK_rpr_B_59_U
# 24     10_DING_8_rpr.pdb   5.66  10_0_solution_4LCK_rpr_B_59_U
# 25     10_DING_9_rpr.pdb  4.428  10_0_solution_4LCK_rpr_B_59_U
#
# [20956 rows x 3 columns]

# %%
# TODO
import warnings
from Bio.PDB.PDBExceptions import PDBConstructionWarning
warnings.filterwarnings('ignore', category=PDBConstructionWarning)

def parse_coordinates(pbd_path: Path):
    parser = PDBParser()

    structure = parser.get_structure(
        "example", DATASET_PATH / f"pz01/1_solution_0_rpr_A_3_G/1_bujnicki_1_rpr.pdb"
    )

    coordinates: list = []
    for model in structure:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    coordinates.append(atom.coord)

    return coordinates

def parse_torsion_angles(tor_path: Path):
    pass

# %% [markdown]
# 2. Krótkie zapoznanie się z dostępnymi przestrzeniami reprezentacji struktur 3D RNA (przestrzenie kartezjańska i kątów torsyjnych) i ich formatami zapisu. Wybór obiecującej przestrzeni na której będziecie Państwo bazować wraz z uzasadnieniem.

# %%
coordinates = parse_coordinates('xd')
coordinates
# Out:
# [array([-20.322,  -0.227,  69.923], dtype=float32),
#  array([-19.307,  -1.206,  71.968], dtype=float32),
#  array([-19.38 ,   0.818,  69.327], dtype=float32),
#  array([-19.303,   0.409,  67.86 ], dtype=float32),
#  array([-18.016,  -3.167,  71.892], dtype=float32),
#  array([-20.706,  -0.14 ,  67.634], dtype=float32),
#  array([-18.208,  -3.283,  70.477], dtype=float32),
#  array([-20.771,  -1.091,  66.433], dtype=float32),
#  array([-18.967,  -2.335,  69.875], dtype=float32),
#  array([-19.534,  -1.305,  70.59 ], dtype=float32),
#  array([-18.561,  -2.163,  72.592], dtype=float32),
#  array([-17.311,  -4.081,  72.546], dtype=float32),
#  array([-19.792,  -0.295,  72.642], dtype=float32),
#  array([-19.927,   2.116,  69.44 ], dtype=float32),
#  array([-19.038,   1.493,  66.991], dtype=float32),
#  array([-21.115,  -0.747,  68.855], dtype=float32),
#  array([-19.894,  -2.186,  66.613], dtype=float32),
#  array([-19.556,  -2.607,  64.166], dtype=float32),
#  array([-18.637,  -4.228,  65.933], dtype=float32),
#  array([-19.687,  -3.296,  65.469], dtype=float32),
#  array([-16.749,   2.813,  72.261], dtype=float32),
#  array([-15.762,   0.86 ,  73.454], dtype=float32),
#  array([-15.702,   3.922,  72.393], dtype=float32),
#  array([-15.383,   4.219,  70.941], dtype=float32),
#  array([-15.048,  -1.062,  72.315], dtype=float32),
#  array([-16.728,   4.018,  70.256], dtype=float32),
#  array([-15.413,  -0.492,  71.053], dtype=float32),
#  array([-16.492,   3.597,  68.808], dtype=float32),
#  array([-15.934,   0.757,  71.059], dtype=float32),
#  array([-16.12 ,   1.453,  72.235], dtype=float32),
#  array([-15.236,  -0.4  ,  73.466], dtype=float32),
#  array([-14.527,  -2.282,  72.353], dtype=float32),
#  array([-15.886,   1.463,  74.521], dtype=float32),
#  array([-16.219,   5.131,  72.896], dtype=float32),
#  array([-14.964,   5.56 ,  70.782], dtype=float32),
#  array([-17.448,   3.074,  71.045], dtype=float32),
#  array([-17.683,   3.102,  68.236], dtype=float32),
#  array([-17.485,   3.014,  65.744], dtype=float32),
#  array([-16.585,   1.109,  67.225], dtype=float32),
#  array([-17.586,   2.159,  66.943], dtype=float32),
#  array([-11.856,   3.771,  74.526], dtype=float32),
#  array([-10.366,  -0.155,  75.52 ], dtype=float32),
#  array([-10.45 ,   4.373,  74.507], dtype=float32),
#  array([-10.532,   5.345,  73.341], dtype=float32),
#  array([-11.396,   1.308,  74.182], dtype=float32),
#  array([-11.962,   5.837,  73.506], dtype=float32),
#  array([-11.675,   0.386,  73.202], dtype=float32),
#  array([-12.516,   6.489,  72.248], dtype=float32),
#  array([-11.3  ,  -0.981,  73.412], dtype=float32),
#  array([-12.351,   2.27 ,  72.474], dtype=float32),
#  array([-10.621,  -1.154,  74.61 ], dtype=float32),
#  array([-9.66 , -0.435, 76.606], dtype=float32),
#  array([-10.76 ,   1.108,  75.365], dtype=float32),
#  array([-12.284,   1.016,  72.117], dtype=float32),
#  array([-11.881,   2.513,  73.739], dtype=float32),
#  array([-10.195,   5.171,  75.64 ], dtype=float32),
#  array([-9.634,  6.425, 73.53 ], dtype=float32),
#  array([-12.735,   4.736,  73.961], dtype=float32),
#  array([-12.61 ,   5.565,  71.189], dtype=float32),
#  array([-11.477,  -1.96 ,  72.688], dtype=float32),
#  array([-13.577,   7.318,  69.67 ], dtype=float32),
#  array([-13.437,   4.859,  68.924], dtype=float32),
#  array([-13.609,   5.873,  69.982], dtype=float32),
#  array([-6.57 ,  2.251, 75.583], dtype=float32),
#  array([-6.9490e+00,  7.4000e-02,  7.4463e+01], dtype=float32),
#  array([-5.09 ,  2.572, 75.382], dtype=float32),
#  array([-5.122,  3.971, 74.785], dtype=float32),
#  array([-8.104, -0.099, 72.428], dtype=float32),
#  array([-6.31 ,  4.557, 75.541], dtype=float32),
#  array([-8.247,  1.326, 72.344], dtype=float32),
#  array([-6.899,  5.781, 74.847], dtype=float32),
#  array([-7.718,  2.06 , 73.354], dtype=float32),
#  array([-7.098,  1.464, 74.429], dtype=float32),
#  array([-7.471, -0.678, 73.455], dtype=float32),
#  array([-8.62 , -0.881, 71.49 ], dtype=float32),
#  array([-6.345, -0.488, 75.378], dtype=float32),
#  array([-4.416,  2.714, 76.611], dtype=float32),
#  array([-3.93 ,  4.668, 75.111], dtype=float32),
#  array([-7.244,  3.5  , 75.729], dtype=float32),
#  array([-7.403,  5.437, 73.578], dtype=float32),
#  array([-7.672,  7.84 , 72.927], dtype=float32),
#  array([-8.448,  5.949, 71.37 ], dtype=float32),
#  array([-8.244,  6.492, 72.726], dtype=float32),
#  array([-2.115, -0.599, 74.505], dtype=float32),
#  array([-3.453, -1.924, 72.895], dtype=float32),
#  array([-0.675, -0.579, 73.992], dtype=float32),
#  array([-0.354,  0.907, 73.964], dtype=float32),
#  array([-4.675, -0.919, 71.163], dtype=float32),
#  array([-1.097,  1.361, 75.216], dtype=float32),
#  array([-4.289,  0.39 , 71.602], dtype=float32),
#  array([-1.344,  2.867, 75.247], dtype=float32),
#  array([-3.482,  0.469, 72.688], dtype=float32),
#  array([-3.066, -0.661, 73.356], dtype=float32),
#  array([-4.267, -2.02 , 71.807], dtype=float32),
#  array([-5.438, -1.065, 70.088], dtype=float32),
#  array([-3.022, -2.955, 73.415], dtype=float32),
#  array([ 0.223, -1.144, 74.921], dtype=float32),
#  array([ 1.043,  1.107, 74.077], dtype=float32),
#  array([-2.29 ,  0.588, 75.277], dtype=float32),
#  array([-2.159,  3.259, 74.166], dtype=float32),
#  array([-1.709,  5.683, 74.607], dtype=float32),
#  array([-3.275,  4.949, 72.707], dtype=float32),
#  array([-2.717,  4.752, 74.059], dtype=float32),
#  array([ 0.82 , -3.813, 71.374], dtype=float32),
#  array([-1.8  , -5.838, 68.579], dtype=float32),
#  array([ 2.021, -3.966, 70.448], dtype=float32),
#  array([ 2.8  , -2.679, 70.673], dtype=float32),
#  array([-1.079, -4.048, 69.722], dtype=float32),
#  array([ 2.551, -2.5  , 72.168], dtype=float32),
#  array([-1.927, -3.169, 69.088], dtype=float32),
#  array([ 2.849, -1.099, 72.688], dtype=float32),
#  array([-2.839, -3.675, 68.112], dtype=float32),
#  array([-0.7  , -1.99 , 70.365], dtype=float32),
#  array([-2.693, -5.038, 67.919], dtype=float32),
#  array([-1.717, -7.103, 68.177], dtype=float32),
#  array([-0.963, -5.393, 69.52 ], dtype=float32),
#  array([-1.674, -1.864, 69.507], dtype=float32),
#  array([-0.313, -3.29 , 70.578], dtype=float32),
#  array([ 2.875, -5.004, 70.876], dtype=float32),
#  array([ 4.167, -2.918, 70.368], dtype=float32),
#  array([ 1.21 , -2.91 , 72.404], dtype=float32),
#  array([ 1.957, -0.145, 72.159], dtype=float32),
#  array([-3.641, -3.072, 67.406], dtype=float32),
#  array([ 3.303,  1.695, 73.205], dtype=float32),
#  array([ 1.198,  2.219, 71.831], dtype=float32),
#  array([ 1.938,  1.342, 72.759], dtype=float32),
#  array([ 1.234, -5.956, 66.566], dtype=float32),
#  array([-0.652, -4.887, 65.373], dtype=float32),
#  array([ 2.118, -6.442, 65.421], dtype=float32),
#  array([ 3.486, -5.87 , 65.763], dtype=float32),
#  array([-0.98 , -2.566, 65.348], dtype=float32),
#  array([ 3.451, -5.965, 67.285], dtype=float32),
#  array([ 0.184, -2.366, 66.164], dtype=float32),
#  array([ 4.453, -5.043, 67.986], dtype=float32),
#  array([ 0.886, -3.464, 66.544], dtype=float32),
#  array([ 0.486, -4.725, 66.171], dtype=float32),
#  array([-1.36 , -3.793, 64.963], dtype=float32),
#  array([-1.691, -1.522, 64.932], dtype=float32),
#  array([-1.011, -6.002, 64.997], dtype=float32),
#  array([ 2.281, -7.843, 65.483], dtype=float32),
#  array([ 4.476, -6.727, 65.215], dtype=float32),
#  array([ 2.1  , -5.751, 67.68 ], dtype=float32),
#  array([ 4.012, -3.702, 67.993], dtype=float32),
#  array([ 6.195, -2.893, 68.923], dtype=float32),
#  array([ 4.261, -1.265, 68.488], dtype=float32),
#  array([ 4.748, -2.596, 68.898], dtype=float32),
#  array([14.25 ,  6.552, 54.464], dtype=float32),
#  array([11.112,  5.637, 51.605], dtype=float32),
#  array([13.404,  7.199, 55.557], dtype=float32),
#  array([14.1  ,  6.744, 56.836], dtype=float32),
#  array([12.643,  5.13 , 53.118], dtype=float32),
#  array([15.549,  6.738, 56.368], dtype=float32),
#  array([12.441,  3.783, 52.979], dtype=float32),
#  array([16.427,  5.823, 57.221], dtype=float32),
#  array([11.473,  3.402, 52.036], dtype=float32),
#  array([13.935,  3.986, 54.462], dtype=float32),
#  array([10.822,  4.361, 51.361], dtype=float32),
#  array([11.997,  6.133, 52.464], dtype=float32),
#  array([11.192,  2.126, 51.785], dtype=float32),
#  array([13.263,  3.06 , 53.837], dtype=float32),
#  array([13.649,  5.265, 54.048], dtype=float32),
#  array([13.436,  8.603, 55.395], dtype=float32),
#  array([13.938,  7.634, 57.93 ], dtype=float32),
#  array([15.556,  6.371, 54.995], dtype=float32),
#  array([16.054,  4.473, 57.038], dtype=float32),
#  array([17.348,  3.775, 59.064], dtype=float32),
#  array([16.053,  2.057, 57.667], dtype=float32),
#  array([16.86 ,  3.289, 57.757], dtype=float32),
#  array([ 9.556,  8.359, 54.851], dtype=float32),
#  array([ 8.756,  6.285, 53.735], dtype=float32),
#  array([ 8.371,  8.944, 55.602], dtype=float32),
#  array([ 8.879,  9.117, 57.024], dtype=float32),
#  array([ 9.263,  4.038, 54.64 ], dtype=float32),
#  array([10.301,  9.571, 56.708], dtype=float32),
#  array([ 9.896,  4.711, 55.748], dtype=float32),
#  array([11.282,  9.393, 57.865], dtype=float32),
#  array([ 9.949,  6.063, 55.804], dtype=float32),
#  array([ 9.445,  6.865, 54.806], dtype=float32),
#  array([ 8.721,  4.896, 53.699], dtype=float32),
#  array([ 8.218,  6.948, 52.85 ], dtype=float32),
#  array([ 8.063, 10.246, 55.148], dtype=float32),
#  array([ 8.098, 10.109, 57.675], dtype=float32),
#  array([ 9.23 ,  2.823, 54.477], dtype=float32),
#  array([10.708,  8.844, 55.548], dtype=float32),
#  array([11.489,  8.018, 58.077], dtype=float32),
#  array([12.931,  8.448, 60.069], dtype=float32),
#  array([12.489,  6.061, 59.237], dtype=float32),
#  array([12.713,  7.494, 58.959], dtype=float32),
#  array([ 4.771,  7.614, 53.93 ], dtype=float32),
#  array([ 3.931,  3.462, 52.763], dtype=float32),
#  array([ 3.299,  7.894, 54.197], dtype=float32),
#  array([ 3.3  ,  8.756, 55.452], dtype=float32),
#  array([ 4.866,  5.061, 54.042], dtype=float32),
#  array([ 4.57 ,  9.558, 55.21 ], dtype=float32),
#  array([ 5.455,  4.16 , 54.901], dtype=float32),
#  array([ 5.136, 10.182, 56.487], dtype=float32),
#  array([ 5.314,  2.76 , 54.656], dtype=float32),
#  array([ 5.85 ,  6.088, 55.705], dtype=float32),
#  array([ 4.495,  2.503, 53.568], dtype=float32),
#  array([ 3.147,  3.054, 51.77 ], dtype=float32),
#  array([ 4.111,  4.779, 52.942], dtype=float32),
#  array([ 6.084,  4.83 , 55.948], dtype=float32),
#  array([ 5.165,  6.316, 54.538], dtype=float32),
#  array([ 2.765,  8.72 , 53.187], dtype=float32),
#  array([ 2.173,  9.623, 55.451], dtype=float32),
#  array([ 5.471,  8.708, 54.512], dtype=float32),
#  array([ 5.791,  9.226, 57.296], dtype=float32),
#  array([ 5.752,  1.811, 55.307], dtype=float32),
#  array([ 6.208, 10.933, 59.084], dtype=float32),
#  array([ 7.07 ,  8.53 , 59.331], dtype=float32),
#  array([ 6.761,  9.699, 58.486], dtype=float32),
#  array([ 0.657,  4.926, 53.477], dtype=float32),
#  array([ 1.205,  2.893, 54.845], dtype=float32),
#  array([-0.781,  4.576, 53.079], dtype=float32),
#  array([-1.484,  5.617, 53.95 ], dtype=float32),
#  array([ 1.97 ,  3.077, 57.058], dtype=float32),
#  array([-0.675,  6.858, 53.641], dtype=float32),
#  array([ 1.846,  4.502, 57.026], dtype=float32),
#  array([-0.94 ,  7.892, 54.733], dtype=float32),
#  array([ 1.397,  5.054, 55.874], dtype=float32),
#  array([ 1.078,  4.289, 54.772], dtype=float32),
#  array([ 1.643,  2.324, 56.005], dtype=float32),
#  array([ 2.392,  2.466, 58.156], dtype=float32),
#  array([ 0.934,  2.171, 53.89 ], dtype=float32),
#  array([-0.922,  4.787, 51.682], dtype=float32),
#  array([-2.879,  5.785, 53.876], dtype=float32),
#  array([ 0.655,  6.355, 53.568], dtype=float32),
#  array([ 0.102,  8.824, 54.751], dtype=float32),
#  array([ 0.133, 10.498, 56.604], dtype=float32),
#  array([ 0.947,  8.09 , 57.009], dtype=float32),
#  array([ 0.778,  9.261, 56.121], dtype=float32),
#  array([-3.468,  1.779, 53.836], dtype=float32),
#  array([-2.301,  0.642, 55.742], dtype=float32),
#  array([-4.919,  1.3  , 53.777], dtype=float32),
#  array([-5.47 ,  2.139, 52.633], dtype=float32),
#  array([-1.499,  1.88 , 57.568], dtype=float32),
#  array([-4.708,  3.446, 52.685], dtype=float32),
#  array([-2.109,  3.08 , 57.075], dtype=float32),
#  array([-5.372,  4.587, 53.497], dtype=float32),
#  array([-2.78 ,  2.994, 55.901], dtype=float32),
#  array([-2.881,  1.808, 55.21 ], dtype=float32),
#  array([-1.612,  0.717, 56.919], dtype=float32),
#  array([-0.785,  1.906, 58.686], dtype=float32),
#  array([-2.463, -0.467, 55.235], dtype=float32),
#  array([-4.961, -0.055, 53.391], dtype=float32),
#  array([-6.857,  2.346, 52.494], dtype=float32),
#  array([-3.441,  3.062, 53.206], dtype=float32),
#  array([-5.129,  5.879, 52.952], dtype=float32),
#  array([-3.166,  5.757, 51.388], dtype=float32),
#  array([-3.628,  7.882, 52.743], dtype=float32),
#  array([-3.654,  6.41 , 52.624], dtype=float32),
#  array([-6.284, -2.303, 55.538], dtype=float32),
#  array([-4.67 , -2.452, 57.395], dtype=float32),
#  array([-7.479, -3.015, 56.158], dtype=float32),
#  array([-8.584, -1.985, 56.079], dtype=float32),
#  array([-4.178, -0.524, 58.862], dtype=float32),
#  array([-8.26 , -1.35 , 54.736], dtype=float32),
#  array([-5.016,  0.265, 57.987], dtype=float32),
#  array([-8.801,  0.069, 54.695], dtype=float32),
#  array([-5.637, -0.3  , 56.921], dtype=float32),
#  array([-5.493, -1.638, 56.615], dtype=float32),
#  array([-4.065, -1.849, 58.483], dtype=float32),
#  array([-4.532, -3.662, 57.203], dtype=float32),
#  array([-7.904, -4.121, 55.39 ], dtype=float32),
#  array([-9.852, -2.617, 56.106], dtype=float32),
#  array([-3.558, -0.108, 59.836], dtype=float32),
#  array([-6.842, -1.382, 54.611], dtype=float32),
#  array([-8.232,  0.724, 53.586], dtype=float32),
#  array([-9.164,  2.957, 52.986], dtype=float32),
#  array([-7.569,  2.679, 54.986], dtype=float32),
#  array([-8.003,  2.301, 53.623], dtype=float32),
#  array([-6.472, -5.566, 59.24 ], dtype=float32),
#  array([-3.397, -4.977, 62.179], dtype=float32),
#  array([-7.171, -6.579, 60.134], dtype=float32),
#  array([-8.645, -6.274, 59.897], dtype=float32),
#  array([-5.124, -4.279, 60.939], dtype=float32),
#  array([-8.608, -5.959, 58.411], dtype=float32),
#  array([-5.17 , -3.026, 61.501], dtype=float32),
#  array([-9.821, -5.179, 57.911], dtype=float32),
#  array([-4.202, -2.685, 62.504], dtype=float32),
#  array([-6.786, -3.135, 60.105], dtype=float32),
#  array([-3.367, -3.754, 62.803], dtype=float32),
#  array([-2.567, -5.93 , 62.58 ], dtype=float32),
#  array([-4.261, -5.293, 61.217], dtype=float32),
#  array([-6.229, -2.304, 60.946], dtype=float32),
#  array([-6.151, -4.351, 60.03 ], dtype=float32),
#  array([-6.964, -7.889, 59.659], dtype=float32),
#  array([-9.432, -7.429, 60.121], dtype=float32),
#  array([-7.37 , -5.312, 58.172], dtype=float32),
#  array([-9.75 , -3.814, 58.267], dtype=float32),
#  array([-4.033, -1.634, 63.119], dtype=float32),
#  array([-11.972,  -3.353,  57.198], dtype=float32),
#  array([-10.573,  -1.447,  58.198], dtype=float32),
#  array([-10.66 ,  -2.742,  57.494], dtype=float32),
#  array([-5.281, -8.152, 63.948], dtype=float32),
#  array([-4.733, -6.121, 65.303], dtype=float32),
#  array([-5.757, -9.21 , 64.944], dtype=float32),
#  array([-7.142, -9.557, 64.421], dtype=float32),
#  array([-6.047, -4.029, 65.054], dtype=float32),
#  array([-6.886, -9.507, 62.926], dtype=float32),
#  array([-6.935, -4.777, 64.205], dtype=float32),
#  array([-8.207, -9.406, 62.161], dtype=float32),
#  array([-6.695, -6.078, 63.927], dtype=float32),
#  array([-5.604, -6.762, 64.414], dtype=float32),
#  array([-4.98 , -4.769, 65.531], dtype=float32),
#  array([-3.841, -6.71 , 65.923], dtype=float32),
#  array([ -5.02 , -10.411,  64.862], dtype=float32),
#  array([ -7.519, -10.877,  64.771], dtype=float32),
#  array([-6.171, -2.845, 65.341], dtype=float32),
#  array([-5.942, -8.459, 62.713], dtype=float32),
#  array([-8.809, -8.15 , 62.375], dtype=float32),
#  array([-11.013,  -8.858,  61.413], dtype=float32),
#  array([-10.586,  -6.419,  62.1  ], dtype=float32),
#  array([-10.104,  -7.703,  61.553], dtype=float32)]

# %%
# works on google colab (sometimes X D)
# import nglview as nv

# nv.show_biopython(structure)
